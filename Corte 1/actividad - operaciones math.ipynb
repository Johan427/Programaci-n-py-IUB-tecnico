# %%
import math

# Punto A #
int= a= 2+(3*(6/2));
print (a);


# Punto B #
int = b= ((4+6)/(2+3));
print(b);

# Punto C #
int=c= pow(4/2, 5);
print(c);

# Punto D #
int=d= pow(4/2, 5+1);
print(d);

# Punto E #
int=e= pow(-3, 2);
print(e);

# Punto F #
int=c= -pow(3, 2);
print(c);
# Out:
# 11.0
# 2.0
# 32.0
# 64.0
# 9
# -9
